# %%
# -*- coding: utf-8 -*
import twitter
import csv
import json
import re
import requests
import lxml.html as html
from urllib2 import urlopen
import pandas as pd
from datetime import datetime, timedelta
from dateutil import tz
import time
import sklearn.cross_validation as cv
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
PREPARED_CSV = "prepared_to_analys.csv"
df = pd.read_csv(PREPARED_CSV, sep=",")

# %%
# Удаляем лишние столбцы
major_features = ["url", "week_day_news", "minutes_since_midnight", "first_time_tweet","follower_sum", "retweeted_count_sum", "favorite_count_sum", "user_listed_count_sum", "last_time_tweet"]
df = df[major_features]

# %%
# С глубоким прискорбием удаляем NA - если ничего не было, пока не будем будмать, что могло быть
df = df.drop_duplicates().dropna()

# %%
# В итоге имеем:
len(df)
# Out:
# 97

# %%
df.head(90)
# Out:
#     index                                                url  week_day_news  \
# 0       0                          https://vc.ru/n/mazurenko              6
# 1      12                           https://vc.ru/n/tur-work              5
# 2      34                        https://vc.ru/n/cards-money              5
# 3     128                      https://vc.ru/n/yota-roborace              4
# 4     165                         https://vc.ru/n/komso-varl              4
# 5     324                    https://vc.ru/n/ya-mail-browser              3
# 6     371                      https://vc.ru/n/no-tur-to-tur              3
# 7     414                 https://vc.ru/n/sgordeev-hyperloop              3
# 8     466                          https://vc.ru/n/ya-meteum              3
# 9     655      https://tjournal.ru/p/visa-ms-porn-censorship              5
# 10    915                     https://tjournal.ru/p/one-like              4
# 11   1055      https://tjournal.ru/p/google-glass-new-patent              4
# 12   1135           https://tjournal.ru/p/1800-2000-prognose              4
# 13   1307       https://tjournal.ru/p/16-thousands-photos-vk              4
# 14   1383          https://tjournal.ru/p/black-friday-psbank              4
# 15   1807          https://tjournal.ru/p/conveyor-is-not-bad              4
# 16   1895             https://tjournal.ru/p/on-russia-not-in              3
# 17   1995                   https://tjournal.ru/p/cosmo-isis              3
# 18   2199        https://tjournal.ru/p/rkn-wiki-noblock-fskn              3
# 19   2271                https://tjournal.ru/p/yandex-meteum              3
# 20   2387              https://tjournal.ru/p/anti-cafe-prank              3
# 21   2479        https://tjournal.ru/p/russian-movie-posters              2
# 22   2615                   https://tjournal.ru/p/krasnoyork              2
# 23   3015                    https://tjournal.ru/p/rkn-cpvls              2
# 24   3131                https://tjournal.ru/p/estonia-li-fi              2
# 25   3767               https://tjournal.ru/p/phuc-dat-bitch              2
# 26   3827              https://tjournal.ru/p/izvestia-ne-gei              2
# 27   3925                        https://vc.ru/n/gett-iphone              2
# 28   3963                               https://vc.ru/p/dojo              2
# 29   4016                    https://vc.ru/p/pay-pal-stories              1
# ..    ...                                                ...            ...
# 60   8407             https://tjournal.ru/p/lawrence-removed              4
# 61   8422   https://tjournal.ru/p/rkn-wiki-narcotics-science              4
# 62   8442         https://tjournal.ru/p/good-dinosaur-review              4
# 63   8490                    https://tjournal.ru/p/coub-boom              4
# 64   8526              https://tjournal.ru/p/watch-paint-dry              3
# 65   8593             https://tjournal.ru/p/putin-washington              3
# 66   8620  https://tjournal.ru/p/twitter-cat-fact-spam-sn...              3
# 67   8642              https://tjournal.ru/p/nfc-cardsmobile              3
# 68   8656        https://tjournal.ru/p/state-of-cyberwarfare              3
# 69   8675               https://tjournal.ru/p/tinder-pr-fail              3
# 70   8702                 https://tjournal.ru/p/parking-fire              3
# 71   8740                https://tjournal.ru/p/truckers-riot              3
# 72   8770        https://tjournal.ru/p/ballistics-calculator              3
# 73   8831                   https://tjournal.ru/p/zano-drone              3
# 74   8942            https://tjournal.ru/p/anonymous-vs-isis              2
# 75   8970    https://tjournal.ru/p/panasonic-magic-megaphone              2
# 76   9004               https://tjournal.ru/p/grugq-telegram              2
# 77   9056          https://tjournal.ru/p/usembru-vs-izvestia              2
# 78   9108           https://tjournal.ru/p/5-reasons-of-metal              2
# 79   9137   https://tjournal.ru/p/samsung-back-to-the-future              2
# 80   9153           https://tjournal.ru/p/rkn-wiki-narcotics              2
# 81   9171                https://tjournal.ru/p/cat-cucumbers              2
# 82   9271             https://tjournal.ru/p/apple-ekb-iphone              2
# 83   9306   https://tjournal.ru/p/star-wars-tatooine-is-real              2
# 84   9320                   https://tjournal.ru/p/new-stalin              2
# 85   9380           https://tjournal.ru/p/aliexpress-culture              2
# 86   9417            https://tjournal.ru/p/salavat-yulaev-vk              1
# 87   9436             https://tjournal.ru/p/snowden-ad-block              1
# 88   9462    https://tjournal.ru/p/hunger-games-final-review              1
# 89   9477           https://tjournal.ru/p/aliexpress-garbage              1
#
#     minutes_since_midnight  first_time_tweet  follower_sum  \
# 0                       64                 2         60688
# 1                     1263                 2         59673
# 2                      747                 4         11879
# 3                     1089                 1         59635
# 4                      965                 2         61416
# 5                     1244                 5         62524
# 6                     1061                 1         59634
# 7                      931                 2         60958
# 8                      775                 2         60212
# 9                     1105                 4        991106
# 10                    1184                24        999358
# 11                    1077                28       1193668
# 12                     840                32       1195192
# 13                     580                 8        992584
# 14                     232                12        199236
# 15                       7                12        994756
# 16                    1084                20        997376
# 17                     952                24        994442
# 18                     900                12        992338
# 19                     784                32       1131906
# 20                     766                28       1192914
# 21                    1379                 4        991106
# 22                    1215                 4        991106
# 23                    1168                12        999644
# 24                    1030                56       1046440
# 25                     952                12        993578
# 26                     889                20        998542
# 27                     717                 2         57799
# 28                     563                 1         57750
# 29                    1131                 3         58643
# ..                     ...               ...           ...
# 60                    1078                 4        252601
# 61                    1029                 4        269769
# 62                     948                 1        244340
# 63                     729                 1        244340
# 64                    1403                 9        255971
# 65                    1228                 4        269466
# 66                    1104                 5        269874
# 67                    1042                 1         24726
# 68                    1037                 4        269870
# 69                     978                 5        288960
# 70                     927                 8        350976
# 71                     926                 6        106605
# 72                     755                 2        244547
# 73                     674                 8        375671
# 74                    1400                 1         24726
# 75                    1373                 7        275786
# 76                    1339                20        463220
# 77                    1235                 9        254251
# 78                    1192                 5        272231
# 79                    1086                 4        245492
# 80                    1021                 7        270452
# 81                     938                 1        244340
# 82                     891                11        357509
# 83                     807                 8        351181
# 84                     778                 8        258535
# 85                     685                 2        245306
# 86                    1375                 3        269112
# 87                    1314                 5        270732
# 88                    1228                 2        244533
# 89                    1192                 5        271396
#
#     retweeted_count_sum  favorite_count_sum  user_listed_count_sum  \
# 0                     6                   3                    688
# 1                    10                  12                    672
# 2                    18                  17                    210
# 3                     2                   6                    672
# 4                    18                  24                    769
# 5                     9                   8                    760
# 6                     8                   1                    672
# 7                     2                   6                    729
# 8                     9                  16                    718
# 9                    32                 136                   4660
# 10                   96                 384                   4776
# 11                   24                  60                  13980
# 12                   68                 140                  13724
# 13                   44                 116                   4684
# 14                    0                   0                   9004
# 15                   60                 188                   4796
# 16                   76                  92                   4924
# 17                   52                 108                   4704
# 18                   48                  28                   4968
# 19                   68                 136                   5232
# 20                   44                  84                  13764
# 21                  108                 308                   4660
# 22                  508                 612                   4660
# 23                   96                 152                   4780
# 24                  124                 156                   5140
# 25                   32                  84                   4764
# 26                   48                  36                   4872
# 27                    2                   2                    669
# 28                    0                  12                    666
# 29                    1                   8                    703
# ..                  ...                 ...                    ...
# 60                    5                  11                   1349
# 61                   15                  10                   1180
# 62                    4                  15                   1159
# 63                    1                  13                   1159
# 64                   48                  43                   1416
# 65                   10                   8                   1492
# 66                    9                  12                   1172
# 67                    0                   0                      5
# 68                    8                  37                   1169
# 69                   15                  36                   1555
# 70                   26                  22                   6570
# 71                    1                   0                   5410
# 72                   10                  10                   1166
# 73                    1                   2                   6574
# 74                    0                   0                      5
# 75                   25                  23                   1277
# 76                   41                  26                   7646
# 77                   44                  42                   1306
# 78                   19                  15                   1213
# 79                    8                   4                   1203
# 80                    6                   6                   1619
# 81                  243                 214                   1159
# 82                   30                  61                   6658
# 83                    5                  15                   6576
# 84                   21                  20                   1339
# 85                   23                 218                   1176
# 86                    6                  11                   1165
# 87                   15                  23                   1199
# 88                    5                  20                   1160
# 89                   38                  73                   1208
#
#     last_time_tweet  DT_Predict
# 0                 8           8
# 1                 9          20
# 2                52          20
# 3                 3           9
# 4                17           6
# 5                 9          17
# 6                11           7
# 7                 3          10
# 8                10           8
# 9                68          54
# 10               84          93
# 11               48          72
# 12               76          69
# 13               56          72
# 14               12          15
# 15               52          80
# 16               72          69
# 17               60          55
# 18               64          54
# 19               68          70
# 20               64          79
# 21               68          53
# 22               96         148
# 23               92          70
# 24              148          91
# 25               52          72
# 26               80          65
# 27               10           8
# 28                1           7
# 29               14           8
# ..              ...         ...
# 60               14          15
# 61               17          25
# 62                7           9
# 63                9           1
# 64               43          26
# 65               19          14
# 66               19          14
# 67               13           7
# 68               14          15
# 69               19          25
# 70               32          25
# 71               23          14
# 72               22          11
# 73                9          14
# 74               20           7
# 75               28          34
# 76               41          83
# 77               40          26
# 78               24          23
# 79               16          15
# 80               10          15
# 81                1          29
# 82               30          33
# 83               11          15
# 84               23          23
# 85               26           1
# 86               16          15
# 87               20          24
# 88               13          11
# 89               36          32
#
# [90 rows x 11 columns]

# %%
x = df[df.columns[1:-1]].as_matrix()
y = df[df.columns[-1]].as_matrix()

# %%
# Делим данные
x_train, x_test, y_train, y_test = cv.train_test_split(x, y, test_size=0.2)

# %%
print "Коэффициенты корреляции Y:"
for i in range(len(major_features)-2):
    print major_features[i+1], "=", np.corrcoef(x[:,i], y)[0][1]
# Out:
# Коэффициенты корреляции Y:
# week_day_news = -0.155063358038
# minutes_since_midnight = -0.118573017224
# first_time_tweet = 0.613310924172
# follower_sum = 0.683869588501
# retweeted_count_sum = 0.549644916153
# favorite_count_sum = 0.637741637598
# user_listed_count_sum = 0.440541350183

# %%
df.last_time_tweet.hist(alpha=0.5, bins=[i*25 for i in range(20)])
plt.title("Tweets after 3 hours")
plt.ylabel("count of urls")
plt.xlabel("count of tweets")
plt.show()

# %%
#df.week_day_news.hist(alpha=0.5, bins=[i for i in range(7)])
S = df.groupby("week_day_news")["last_time_tweet"].sum()
plt.pie(S.as_matrix(), labels=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]);
plt.show();

# %%
plt.figure(figsize=(8,8))
plt.plot(df["last_time_tweet"].as_matrix(), df["first_time_tweet"].as_matrix(), 'ro',  alpha=0.6)
plt.title("Tweet Count")
plt.xlabel("Count Of Tweets after 180 minutes")
plt.ylabel("Count Of Tweets after 10 minutes")
plt.xlim(0, 350)
plt.ylim(0, 350)
plt.grid(b=True, which='both', color='0.65',linestyle='-')
plt.rcParams.update({'font.size': 14})

# %%
df[df["first_time_tweet"]> 20]
# Out:
#                                                 url  week_day_news  \
# 915                  https://tjournal.ru/p/one-like              4
# 1055  https://tjournal.ru/p/google-glass-new-patent              4
# 1135       https://tjournal.ru/p/1800-2000-prognose              4
# 1995               https://tjournal.ru/p/cosmo-isis              3
# 2271            https://tjournal.ru/p/yandex-meteum              3
# 2387          https://tjournal.ru/p/anti-cafe-prank              3
# 3131            https://tjournal.ru/p/estonia-li-fi              2
# 4379          https://tjournal.ru/p/condomchallenge              2
# 4895          https://tjournal.ru/p/laquan-mcdonald              2
# 5119    https://tjournal.ru/p/man-in-high-castle-pr              1
# 5423    https://tjournal.ru/p/ampelonskyi-wikipedia              1
# 6423      https://tjournal.ru/p/fuboy-epic-trolling              1
# 6747            https://tjournal.ru/p/tech-faces-vk              0
# 7471        https://tjournal.ru/p/afisha-eda-skrepy              0
# 7583    https://tjournal.ru/p/knitting-is-dangerous              0
# 7915       https://tjournal.ru/p/apple-one-question              6
#
#       minutes_since_midnight  first_time_tweet  follower_sum  \
# 915                     1184                24        999358
# 1055                    1077                28       1193668
# 1135                     840                32       1195192
# 1995                     952                24        994442
# 2271                     784                32       1131906
# 2387                     766                28       1192914
# 3131                    1030                56       1046440
# 4379                     767                24       1001916
# 4895                     602                40       1409564
# 5119                    1224                36       1148064
# 5423                     777                24        426420
# 6423                       3                80       1975956
# 6747                    1229                28        995976
# 7471                     980                28       1002066
# 7583                     688                28       1458146
# 7915                     978                40       1454162
#
#       retweeted_count_sum  favorite_count_sum  user_listed_count_sum  \
# 915                    96                 384                   4776
# 1055                   24                  60                  13980
# 1135                   68                 140                  13724
# 1995                   52                 108                   4704
# 2271                   68                 136                   5232
# 2387                   44                  84                  13764
# 3131                  124                 156                   5140
# 4379                  196                 260                   4848
# 4895                   36                  32                  27836
# 5119                   80                 160                   7368
# 5423                    0                   0                  21640
# 6423                  336                 300                  31732
# 6747                   80                 180                   5052
# 7471                   40                 104                   5192
# 7583                   40                  68                  15964
# 7915                   32                 160                  27056
#
#       last_time_tweet
# 915                84
# 1055               48
# 1135               76
# 1995               60
# 2271               68
# 2387               64
# 3131              148
# 4379              332
# 4895               56
# 5119              104
# 5423               88
# 6423              212
# 6747               84
# 7471               80
# 7583               76
# 7915               92

# %%
def plot(y_test, y_predicted,title="", text=""):
    plt.figure(figsize=(9,9))
    plt.plot(y_test, y_predicted, 'ro', label="predicted", alpha=0.7)
    plt.title(title)
    plt.xlabel("Y_TEST")
    plt.ylabel("Y_PREDICTED")
    
    max_y = max(max(y_true), max(y_predicted))+10
    
    plt.xlim(0, max_y)
    plt.ylim(0, max_y)
    #plt.legend()
    plt.text(0.05*max_y, max_y-0.05*max_y, "mse="+text, fontsize=15)
    
    plt.plot([0, max_y], [0, max_y], color='black', alpha=0.5)
    plt.grid(b=True, which='both', color='0.65',linestyle='-')
    
    plt.show()

# %%
def split_data(train_index, test_index):
    x_train = x[train_index]
    y_train = y[train_index]
    
    x_test = x[test_index]
    y_test = y[test_index]
    
    return x_train, x_test, y_train, y_test

# %%
loo = cv.LeaveOneOut(len(y))

# %% [markdown]
# ## Деревья

# %%
from sklearn.tree import DecisionTreeRegressor

y_predicted = []
y_true = []

for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    dtree = DecisionTreeRegressor(max_depth=3)
    dtree.fit(x_train, y_train)
    y_pred = dtree.predict(x_test[0])
    y_predicted.append(y_pred[0])
    y_true.append(y_test[0])
    

mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="DecisionTree Y", text=str(mse))

# %%
from sklearn.tree import DecisionTreeRegressor

y_predicted = []
y_true = []


for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    dtree = DecisionTreeRegressor(max_depth=4, random_state=600)
    dtree.fit(x_train, np.log(y_train))
    y_pred = dtree.predict(x_test[0])
    y_predicted.append(np.exp(y_pred[0]))
    y_true.append(y_test[0])

mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="DecisionTree Ln(Y)", text=str(mse))

# %% [markdown]
# В целом, конечно, дерево решений работает плохо, но выбросы оно вполне себе улавливает

# %%
y_true = np.asarray(y_true)
y_predicted = np.asarray(y_predicted)
BIG = 100
y_big_true = y_true[y_true>BIG]
y_big_predicted = y_predicted[y_true>BIG]

# %%
a = pd.DataFrame([y_big_true, y_big_predicted])
a.index=["y_true","y_predicted"]
a
# Out:
#                       0    1          2    3    4    5
# y_true       148.000000  332  104.00000  292  212  148
# y_predicted   90.914575  292   69.96793  332  292   96

# %% [markdown]
# Вопрос к Михаилу.
#
# Как замерять RandomForest и другие рандомные методы. Раз через раз дает катастрофическую разницу. 400!

# %%
df.reset_index(inplace=True)

# %%
predic = pd.Series(np.around(y_predicted))

# %%
df["DT_Predict"]=predic
df_LTT = df[["url", "last_time_tweet", "DT_Predict"]]
df_LTT[df_LTT["last_time_tweet"]>70]
# Out:
#                                                   url  last_time_tweet  \
# 10                     https://tjournal.ru/p/one-like               84
# 12           https://tjournal.ru/p/1800-2000-prognose               76
# 16             https://tjournal.ru/p/on-russia-not-in               72
# 22                   https://tjournal.ru/p/krasnoyork               96
# 23                    https://tjournal.ru/p/rkn-cpvls               92
# 24                https://tjournal.ru/p/estonia-li-fi              148
# 26              https://tjournal.ru/p/izvestia-ne-gei               80
# 38              https://tjournal.ru/p/condomchallenge              332
# 39       https://tjournal.ru/p/creationists-vs-google               76
# 41                  https://tjournal.ru/p/rocket-back               76
# 42        https://tjournal.ru/p/man-in-high-castle-pr              104
# 43  https://tjournal.ru/p/nohcho-charlie-hebdo-twi...               80
# 46        https://tjournal.ru/p/ampelonskyi-wikipedia               88
# 47          https://tjournal.ru/p/automate-everything              292
# 48                      https://tjournal.ru/p/m10-m11               76
# 49          https://tjournal.ru/p/fuboy-epic-trolling              212
# 50                https://tjournal.ru/p/tech-faces-vk               84
# 51     https://tjournal.ru/p/stina-sanders-vs-glamour               76
# 52        https://tjournal.ru/p/life-in-internet-cafe              148
# 53            https://tjournal.ru/p/afisha-eda-skrepy               80
# 54        https://tjournal.ru/p/knitting-is-dangerous               76
# 55       https://tjournal.ru/p/brussels-lockdown-cats               76
# 56           https://tjournal.ru/p/apple-one-question               92
#
#     DT_Predict
# 10          93
# 12          69
# 16          69
# 22         148
# 23          70
# 24          91
# 26          65
# 38         292
# 39          54
# 41          71
# 42          70
# 43          65
# 46          36
# 47         332
# 48          73
# 49         292
# 50          74
# 51          52
# 52          96
# 53          70
# 54          71
# 55          53
# 56          58

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# Подбираем параметр

# %%
alpha = [0.01, 0.1, 1, 10, 1e2, 1e3, 1e4, 1e5, 2e5, 4e5, 8e5, 1e6, 2e6, 4e6, 7e6, 1e7, 1e8]

mse = []
for al in alpha:
    y_predicted = []
    y_true = []

    for train_index, test_index in loo:
        x_train, x_test, y_train, y_test = split_data(train_index, test_index)
        model = Ridge(alpha=al)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test[0])
        y_predicted.append(y_pred[0])
        y_true.append(y_test[0])
    
    cur_mse = mean_squared_error(y_true, y_predicted)
    print cur_mse
    mse.append(cur_mse)

best_alpha = alpha[mse.index(min(mse))]
print "Best Aplha = ", best_alpha
#plot(y_true, y_predicted, title="DecisionTree Log(Y)")
# Out:
# 1360.08163227
# 1360.0743121
# 1360.00177308
# 1359.33790625
# 1356.12333518
# 1362.68952671
# 1462.27943437
# 1485.86145706
# 1464.52341871
# 1449.76462398
# 1456.8697789
# 1465.51251366
# 1509.22963297
# 1562.80059614
# 1599.77379802
# 1617.98449726
# 1659.15868566
# Best Aplha =  100.0

# %%
y_predicted = []
y_true = []

for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    model = Ridge(alpha=best_alpha)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test[0])
    y_predicted.append(y_pred[0])
    y_true.append(y_test[0])

mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="Ridge Y", text=str(mse))
print model.coef_
# Out:
# [ -1.33390531e+00  -1.05831161e-02   1.74427901e+00   3.38397949e-05
#    7.79517799e-02   1.25574928e-01  -1.99108646e-03]

# %% [markdown]
# Теперь логарифм

# %%
alpha = [0.01, 0.1, 1, 10, 1e2, 1e3, 1e4, 1e5, 2e5, 4e5, 8e5, 1e6, 2e6, 4e6, 7e6, 1e7, 1e8]

mse = []
for al in alpha:
    y_predicted = []
    y_true = []

    for train_index, test_index in loo:
        x_train, x_test, y_train, y_test = split_data(train_index, test_index)
        model = Ridge(alpha=al)
        model.fit(x_train, np.log(y_train))
        y_pred = model.predict(x_test[0])
        y_predicted.append(np.exp(y_pred[0]))
        y_true.append(y_test[0])

    cur_mse = mean_squared_error(y_true, y_predicted)
    print cur_mse
    mse.append(cur_mse)


best_alpha = alpha[mse.index(min(mse))]
print "Best Aplha = ", best_alpha
#plot(y_true, y_predicted, title="DecisionTree Log(Y)")
# Out:
# 4970.28789656
# 4970.19820592
# 4969.29803785
# 4959.98906943
# 4848.79732673
# 3860.72210678
# 2322.9365686
# 2002.16007564
# 1964.90211876
# 1934.85930432
# 1913.36130569
# 1908.96239375
# 1904.70425378
# 1914.83290311
# 1933.03748189
# 1948.7816952
# 2069.79406598
# Best Aplha =  2000000.0

# %%
y_predicted = []
y_true = []

for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    model = Ridge(alpha=best_alpha)
    model.fit(x_train, np.log(y_train))
    y_pred = model.predict(x_test[0])
    y_predicted.append(np.exp(y_pred[0]))
    y_true.append(y_test[0])
    
mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="Ridge ln(Y)", text=str(mse))
print model.coef_
# Out:
# [  1.05885875e-06   3.71387811e-04   3.87004482e-05   2.05296159e-06
#    2.15278367e-04   2.76335315e-04  -1.18873229e-05]

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
y_predicted = []
y_true = []

for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    model = RandomForestRegressor(n_estimators=20)
    model.fit(x_train, (y_train))
    y_pred = model.predict(x_test[0])
    y_predicted.append((y_pred[0]))
    y_true.append(y_test[0])

mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="Random Forest Y", text=str(mse))

# %% [markdown]
# #### Теперь логарифм

# %%
y_predicted = []
y_true = []

for train_index, test_index in loo:
    x_train, x_test, y_train, y_test = split_data(train_index, test_index)
    model = RandomForestRegressor(n_estimators=20)
    model.fit(x_train, np.log(y_train))
    y_pred = model.predict(x_test[0])
    y_predicted.append(np.exp(y_pred[0]))
    y_true.append(y_test[0])

mse = mean_squared_error(y_true, y_predicted)
plot(y_true, y_predicted, title="Random Forest ln(Y)", text=str(mse))

# %%
y_true
# Out:
# [8.0,
#  9.0,
#  52.0,
#  3.0,
#  17.0,
#  9.0,
#  11.0,
#  3.0,
#  10.0,
#  68.0,
#  84.0,
#  48.0,
#  76.0,
#  56.0,
#  12.0,
#  52.0,
#  72.0,
#  60.0,
#  64.0,
#  68.0,
#  64.0,
#  68.0,
#  96.0,
#  92.0,
#  148.0,
#  52.0,
#  80.0,
#  10.0,
#  1.0,
#  14.0,
#  4.0,
#  4.0,
#  23.0,
#  5.0,
#  6.0,
#  6.0,
#  3.0,
#  36.0,
#  332.0,
#  76.0,
#  56.0,
#  76.0,
#  104.0,
#  80.0,
#  32.0,
#  64.0,
#  88.0,
#  292.0,
#  76.0,
#  212.0,
#  84.0,
#  76.0,
#  148.0,
#  80.0,
#  76.0,
#  76.0,
#  92.0,
#  29.0,
#  32.0,
#  12.0,
#  14.0,
#  17.0,
#  7.0,
#  9.0,
#  43.0,
#  19.0,
#  19.0,
#  13.0,
#  14.0,
#  19.0,
#  32.0,
#  23.0,
#  22.0,
#  9.0,
#  20.0,
#  28.0,
#  41.0,
#  40.0,
#  24.0,
#  16.0,
#  10.0,
#  1.0,
#  30.0,
#  11.0,
#  23.0,
#  26.0,
#  16.0,
#  20.0,
#  13.0,
#  36.0,
#  9.0,
#  12.0,
#  26.0,
#  15.0,
#  16.0,
#  29.0,
#  7.0]
